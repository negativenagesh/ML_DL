# %% [markdown]
# # 1. Loadind data

# %%
import pandas as pd

# %%
data=pd.read_csv('sonar.csv',header=None)
data.head(10)
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 5  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# 6  0.0317  0.0956  0.1321  0.1408  0.1674  0.1710  0.0731  0.1401  0.2083
# 7  0.0519  0.0548  0.0842  0.0319  0.1158  0.0922  0.1027  0.0613  0.1465
# 8  0.0223  0.0375  0.0484  0.0475  0.0647  0.0591  0.0753  0.0098  0.0684
# 9  0.0164  0.0173  0.0347  0.0070  0.0187  0.0671  0.1056  0.0697  0.0962
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# ...

# %%
data_features=data.drop(columns=[60])
data_features.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      50      51      52      53      54      55      56  \
# 0  0.2111  ...  0.0232  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180
# 1  0.2872  ...  0.0125  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140
# 2  0.6194  ...  0.0033  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316
# 3  0.1264  ...  0.0241  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050
# 4  0.4459  ...  0.0156  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072
#
#        57      58      59
# 0  0.0084  0.0090  0.0032
# 1  0.0049  0.0052  0.0044
# ...

# %%
target=data[60]
target.head()
# Out:
# 0    R
# 1    R
# 2    R
# 3    R
# 4    R
# Name: 60, dtype: object

# %% [markdown]
# # 2. Histogram of features(60)

# %%
import seaborn as sea
import matplotlib.pyplot as plt
for column in range(60):
    sea.histplot(data=data[column])
    plt.show()

# %% [markdown]
# # 3. Applying Box-Cox

# %%
from sklearn.preprocessing import MinMaxScaler

scale=MinMaxScaler(feature_range=(1,2))
scaled_data_features=pd.DataFrame(scale.fit_transform(data_features))

# scaled_data_features=scale.fit(data_features)
# scaled_data_features=scale.transform(scaled_data_features)
# transformed_data_features=scale.transform([[1,2]])
# data_features=pd.DataFrame(scale.transform(data_features))

# %%
from sklearn.preprocessing import power_transform

power_tran=pd.DataFrame(power_transform(scaled_data_features,method='box-cox'))

# %% [markdown]
# # 4. Histogram of transformed features

# %%
for column in range(60):
    sea.histplot(data=power_tran[column])
    plt.show()

# %% [markdown]
# # 5. PCA, plotting pc1 and pc2 using seaborn scatterplot

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
power_trans1=pca.fit(power_tran)

# %%
power_trans1.components_
# Out:
# array([[ 0.16435013,  0.18737652,  0.18357846,  0.18650547,  0.16226909,
#          0.15573774,  0.14978707,  0.16126925,  0.1416071 ,  0.14096244,
#          0.17007471,  0.13765088,  0.17604694,  0.2145915 ,  0.21573307,
#          0.21516514,  0.18204804,  0.15052614,  0.16060002,  0.16385583,
#          0.14233032,  0.07970632,  0.01800534, -0.03181463, -0.09439529,
#         -0.13258423, -0.1458634 , -0.15611321, -0.16708457, -0.12896045,
#         -0.11274433, -0.09267011, -0.08862684, -0.05421723, -0.0241866 ,
#         -0.01191517,  0.00867116,  0.04002074,  0.0569999 ,  0.05705389,
#          0.05601712,  0.05705568,  0.03655694,  0.04205319,  0.07401573,
#          0.04724097,  0.05944739,  0.07693764,  0.10024631,  0.08807522,
#          0.12727099,  0.11660358,  0.10429836,  0.1429369 ,  0.14296086,
#          0.12498486,  0.12097305,  0.15886938,  0.14761985,  0.12377118],
#        [ 0.057495  ,  0.08680177,  0.06059461,  0.01538859, -0.02152311,
# ...

# %%
pcaeddata=pd.DataFrame(data=power_trans1.components_.T,columns=['pc1','pc2'])

# %%
sea.scatterplot(data=pcaeddata)
plt.show()
